# %%
n = ['joão', 'maria', 'Kleber','Caio', 'sarah']
v = [500,300,210,900,780]

print('Lista de Clientes - Banco xxxx')

i = len(v)
print('Nome  Saldo')
for x in range(i):
    print(n[x] , v[x] )
# Out:
# Lista de Clientes - Banco xxxx
# Nome  Saldo
# joão 500
# maria 300
# Kleber 210
# Caio 900
# sarah 780
